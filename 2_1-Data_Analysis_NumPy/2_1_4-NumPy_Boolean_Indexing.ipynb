# %% [markdown]
# ---
# # Data Science and Artificial Intelliegence Practicum
# ## 2.1-modul. Data Analysis: NumPy
# ---

# %% [markdown]
# ## 2.1.3 - Boolean Indexing

# %%
import numpy as np

# %%
# Names
names = np.array(['Hasan', 'Husan', 'Mirzabek', 'Elyor', 'Hasan', 'Javohir', 'Elyor'])
names
# Out:
# array(['Hasan', 'Husan', 'Mirzabek', 'Elyor', 'Hasan', 'Javohir', 'Elyor'],
#       dtype='<U8')

# %%
# Data
data = np.random.randn(7, 4)
data
# Out:
# array([[-2.05461503, -0.27117699, -0.187091  , -0.36626331],
#        [ 1.15161431,  0.01551423,  1.75320118,  1.37669111],
#        [-0.11359492,  1.71793788, -0.92796192,  1.21447225],
#        [ 0.14995478, -0.95420184, -0.14884612,  0.34081155],
#        [ 0.35536154, -1.57062875,  0.48502826,  0.5321216 ],
#        [-0.84026932, -0.27624593,  0.19083656, -1.58840929],
#        [ 0.08390862,  0.99524438, -0.04119694,  0.13312157]])

# %%
names == "Javohir"
# Out:
# array([False, False, False, False, False,  True, False])

# %%
data[names == "Javohir"]  # Javohir's data
# Out:
# array([[-0.84026932, -0.27624593,  0.19083656, -1.58840929]])

# %%
data[names == "Elyor"]  # Elyor's data
# Out:
# array([[ 0.14995478, -0.95420184, -0.14884612,  0.34081155],
#        [ 0.08390862,  0.99524438, -0.04119694,  0.13312157]])

# %%
data[names == "Hasan", 2:]  # Hasan's data's last 2 columns
# Out:
# array([[-0.187091  , -0.36626331],
#        [ 0.48502826,  0.5321216 ]])

# %%
data[names != "Hasan"]  # returns everyone's data except Hasan's
# Out:
# array([[ 1.15161431,  0.01551423,  1.75320118,  1.37669111],
#        [-0.11359492,  1.71793788, -0.92796192,  1.21447225],
#        [ 0.14995478, -0.95420184, -0.14884612,  0.34081155],
#        [-0.84026932, -0.27624593,  0.19083656, -1.58840929],
#        [ 0.08390862,  0.99524438, -0.04119694,  0.13312157]])

# %%
data[~(names == "Hasan")] # "~"" equivalent to "!="
# Out:
# array([[ 1.15161431,  0.01551423,  1.75320118,  1.37669111],
#        [-0.11359492,  1.71793788, -0.92796192,  1.21447225],
#        [ 0.14995478, -0.95420184, -0.14884612,  0.34081155],
#        [-0.84026932, -0.27624593,  0.19083656, -1.58840929],
#        [ 0.08390862,  0.99524438, -0.04119694,  0.13312157]])

# %%
mask = (names=="Hasan") | (names=="Elyor")  # "|" -> or

# %%
data[mask]  # Hasan and Elyor's data
# Out:
# array([[-2.05461503, -0.27117699, -0.187091  , -0.36626331],
#        [ 0.14995478, -0.95420184, -0.14884612,  0.34081155],
#        [ 0.35536154, -1.57062875,  0.48502826,  0.5321216 ],
#        [ 0.08390862,  0.99524438, -0.04119694,  0.13312157]])

# %%
data
# Out:
# array([[-2.05461503, -0.27117699, -0.187091  , -0.36626331],
#        [ 1.15161431,  0.01551423,  1.75320118,  1.37669111],
#        [-0.11359492,  1.71793788, -0.92796192,  1.21447225],
#        [ 0.14995478, -0.95420184, -0.14884612,  0.34081155],
#        [ 0.35536154, -1.57062875,  0.48502826,  0.5321216 ],
#        [-0.84026932, -0.27624593,  0.19083656, -1.58840929],
#        [ 0.08390862,  0.99524438, -0.04119694,  0.13312157]])

# %%
data[data < 0]
# Out:
# array([-2.05461503, -0.27117699, -0.187091  , -0.36626331, -0.11359492,
#        -0.92796192, -0.95420184, -0.14884612, -1.57062875, -0.84026932,
#        -0.27624593, -1.58840929, -0.04119694])
