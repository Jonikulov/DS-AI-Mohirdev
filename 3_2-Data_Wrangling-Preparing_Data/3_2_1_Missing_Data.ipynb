# %% [markdown]
# ---
# # Data Science and Artificial Intelliegence Practicum
# ## 3.2-modul. Data Wrangling
# ---

# %% [markdown]
# ## 3.2.1 - Missing data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %% [markdown]
# ### `isna` or `isnull`
# Detect missing values.
#
# `DataFrame.isnull` is an alias for `DataFrame.isna`.

# %%
df.isnull()
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0        False       False       False   False        False             False
# 1        False       False        True   False        False             False
# 2        False       False       False   False        False             False
# 3        False       False       False   False        False             False
# 4        False       False       False   False        False             False
# ...        ...         ...         ...     ...          ...               ...
# 81       False       False       False   False        False             False
# 82       False       False        True   False         True             False
# 86       False       False       False    True        False             False
# 87       False       False       False   False         True             False
# 88       False       False       False   False        False             False
#
#        horsepower  average-mileage  price
# index
# 0            True            False  False
# 1           False            False  False
# 2           False             True  False
# 3           False            False  False
# 4            True             True  False
# ...           ...              ...    ...
# 81          False            False  False
# 82          False            False  False
# 86          False             True  False
# 87          False            False  False
# 88           True            False  False
#
# [61 rows x 9 columns]

# %% [markdown]
# Because the boolean values ​​are `True=1`,`False=0` we can count `NaN` values in each column with `sum` method

# %%
df.isnull().sum()
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %% [markdown]
# `NaN` values in percentage

# %%
nulls = df.isnull().sum()  # number of NaN values
rows = df.shape[0]  # number of rows
(nulls / rows) * 100  # percentage of NaN values
# Out:
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %% [markdown]
# ### `notna` or `notnull`
# Detect existing (non-missing) values.
#
# `DataFrame.notnull` is an alias for `DataFrame.notna`.

# %%
df.notna()
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0         True        True        True    True         True              True
# 1         True        True       False    True         True              True
# 2         True        True        True    True         True              True
# 3         True        True        True    True         True              True
# 4         True        True        True    True         True              True
# ...        ...         ...         ...     ...          ...               ...
# 81        True        True        True    True         True              True
# 82        True        True       False    True        False              True
# 86        True        True        True   False         True              True
# 87        True        True        True    True        False              True
# 88        True        True        True    True         True              True
#
#        horsepower  average-mileage  price
# index
# 0           False             True   True
# 1            True             True   True
# 2            True            False   True
# 3            True             True   True
# 4           False            False   True
# ...           ...              ...    ...
# 81           True             True   True
# 82           True             True   True
# 86           True            False   True
# 87           True             True   True
# 88          False             True   True
#
# [61 rows x 9 columns]

# %%
df.notna().sum()
# Out:
# company             61
# body-style          61
# wheel-base          46
# length              48
# engine-type         49
# num-of-cylinders    61
# horsepower          45
# average-mileage     46
# price               58
# dtype: int64

# %% [markdown]
# Non-missing (valid) values in percentage

# %%
notnulls = df.notna().sum()
rows = df.shape[0]
(notnulls / rows) * 100
# Out:
# company             100.000000
# body-style          100.000000
# wheel-base           75.409836
# length               78.688525
# engine-type          80.327869
# num-of-cylinders    100.000000
# horsepower           73.770492
# average-mileage      75.409836
# price                95.081967
# dtype: float64

# %% [markdown]
# ### `dropna`
# Remove missing values.

# %%
df.shape
# Out:
# (61, 9)

# %%
# remove NaN values
df2 = df.dropna()
df2.shape
# Out:
# (14, 9)

# %%
df2
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 3                 four       102.0             24.0  13950.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0
# 17                four        70.0             38.0   6295.0
# 19                four        68.0             31.0   6377.0
# 28                four       101.0             24.0  12945.0
# 34                 six       176.0             15.0  35550.0
# 37                four        68.0             31.0   6095.0
# 38                four        68.0             31.0   6795.0
# 54                four        69.0             31.0   6649.0
# 56                four        69.0             31.0   7349.0
# 62                 six       207.0             17.0  37028.0
# 69                four        62.0             31.0   6918.0
# 81                four        85.0             27.0   7975.0

# %% [markdown]
# #### `axis` parameter

# %%
df.dropna(axis=1)  # remove NaN by columns
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %% [markdown]
# #### `thresh` parameter
# `thresh` tells minimum amount of `NaN` values to drop

# %%
# detect valid (non-missing) values
df.notna().sum()
# Out:
# company             61
# body-style          61
# wheel-base          48
# length              49
# engine-type         51
# num-of-cylinders    61
# horsepower          47
# average-mileage     46
# price               58
# dtype: int64

# %%
# keep only the rows having 9 or more valid data
df.dropna(axis=0, thresh=9)
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 66         toyota    hatchback        95.7   158.7         ohc
# 67         toyota    hatchback        95.7   158.7         ohc
# 68         toyota    hatchback        95.7   158.7         ohc
# 69         toyota        wagon        95.7   169.7         ohc
# 70         toyota        wagon        95.7   169.7         ohc
# 71         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 3                 four       102.0             24.0  13950.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0
# 17                four        70.0             38.0   6295.0
# 19                four        68.0             31.0   6377.0
# 28                four       101.0             24.0  12945.0
# 34                 six       176.0             15.0  35550.0
# 37                four        68.0             31.0   6095.0
# 38                four        68.0             31.0   6795.0
# 54                four        69.0             31.0   6649.0
# 56                four        69.0             31.0   7349.0
# 62                 six       207.0             17.0  37028.0
# 66                four        62.0             35.0   5348.0
# 67                four        62.0             31.0   6338.0
# 68                four        62.0             31.0   6488.0
# 69                four        62.0             31.0   6918.0
# 70                four        62.0             27.0   7898.0
# 71                four       156.0             27.0   8778.0
# 81                four        85.0             27.0   7975.0

# %%
# keep only columns where 80% or more valid data is available
df.dropna(axis=1, thresh=df.shape[0]*0.8)
# Out:
#            company   body-style  length engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible   168.8        dohc             four  13495.0
# 1      alfa-romero  convertible   168.8        dohc             four  16500.0
# 2      alfa-romero    hatchback   171.2        ohcv              six  16500.0
# 3             audi        sedan   176.6         ohc             four  13950.0
# 4             audi        sedan   176.6         ohc             five  17450.0
# ...            ...          ...     ...         ...              ...      ...
# 81      volkswagen        sedan   171.7         ohc             four   7975.0
# 82      volkswagen        sedan   171.7         NaN             four   7995.0
# 86      volkswagen        sedan     NaN         ohc             four   9995.0
# 87           volvo        sedan   188.8         NaN             four  12940.0
# 88           volvo        wagon   188.8         ohc             four  13415.0
#
# [61 rows x 6 columns]

# %% [markdown]
# #### `subset` parameter
# `subset` parameter enables to specify the subset of columns where `dropna` will look for missing values.

# %%
df.dropna(subset=['engine-type', 'price', 'length'])
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 0        alfa-romero  convertible        88.6   168.8        dohc
# 1        alfa-romero  convertible         NaN   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 10               bmw        sedan         NaN   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 13               bmw        sedan       103.5   189.0         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 16         chevrolet    hatchback        88.4   141.1           l
# 17         chevrolet    hatchback        94.5   155.9         ohc
# 18         chevrolet        sedan         NaN   158.8         ohc
# 19             dodge    hatchback        93.7   157.3         ohc
# 28             honda        sedan        96.5   175.4         ohc
# 29             honda        sedan         NaN   169.1         ohc
# 30             isuzu        sedan         NaN   170.7         ohc
# 34            jaguar        sedan       113.0   199.6        dohc
# 35            jaguar        sedan         NaN   191.7        ohcv
# 37             mazda    hatchback        93.1   159.1         ohc
# 38             mazda    hatchback        93.1   159.1         ohc
# 43             mazda        sedan       104.9   175.0         ohc
# 45     mercedes-benz        wagon         NaN   190.9         ohc
# 49        mitsubishi    hatchback         NaN   157.3         ohc
# 52        mitsubishi        sedan        96.3   172.4         ohc
# 54            nissan        sedan        94.5   165.3         ohc
# 55            nissan        sedan         NaN   165.3         ohc
# 56            nissan        wagon        94.5   170.2         ohc
# 57            nissan        sedan       100.4   184.6        ohcv
# 62           porsche  convertible        89.5   168.9        ohcf
# 66            toyota    hatchback        95.7   158.7         ohc
# 67            toyota    hatchback        95.7   158.7         ohc
# 68            toyota    hatchback        95.7   158.7         ohc
# 69            toyota        wagon        95.7   169.7         ohc
# 70            toyota        wagon        95.7   169.7         ohc
# 71            toyota        wagon        95.7   169.7         ohc
# 79            toyota        wagon       104.5   187.8        dohc
# 81        volkswagen        sedan        97.3   171.7         ohc
# 88             volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0
# 10                four       101.0             23.0  16925.0
# 11                 six       121.0              NaN  20970.0
# 13                 six         NaN             16.0  30760.0
# 15                 six       182.0              NaN  36880.0
# 16               three         NaN             47.0   5151.0
# 17                four        70.0             38.0   6295.0
# 18                four        70.0              NaN   6575.0
# 19                four        68.0             31.0   6377.0
# 28                four       101.0             24.0  12945.0
# 29                four         NaN             25.0  10345.0
# 30                four        78.0             24.0   6785.0
# 34                 six       176.0             15.0  35550.0
# 35              twelve       262.0             13.0  36000.0
# 37                four        68.0             31.0   6095.0
# 38                four        68.0             31.0   6795.0
# 43                four         NaN              NaN  18344.0
# 45                five       123.0             22.0  28248.0
# 49                four         NaN             37.0   5389.0
# 52                four         NaN             25.0   8189.0
# 54                four        69.0             31.0   6649.0
# 55                four        69.0             31.0   6849.0
# 56                four        69.0             31.0   7349.0
# 57                 six       152.0              NaN  13499.0
# 62                 six       207.0             17.0  37028.0
# 66                four        62.0             35.0   5348.0
# 67                four        62.0             31.0   6338.0
# 68                four        62.0             31.0   6488.0
# 69                four        62.0             31.0   6918.0
# 70                four        62.0             27.0   7898.0
# 71                four       156.0             27.0   8778.0
# 79                 six       156.0              NaN  15750.0
# 81                four        85.0             27.0   7975.0
# 88                four         NaN             23.0  13415.0

# %% [markdown]
# ### `fillna`
# Fill `NA`/`NaN` values using the specified method.

# %%
# replace all NaN values with 0
df.fillna(0)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         0.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         0.0   171.7           0
# 86      volkswagen        sedan        97.3     0.0         ohc
# 87           volvo        sedan       104.3   188.8           0
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         0.0             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              0.0  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         0.0              0.0  17450.0
# ...                ...         ...              ...      ...
# 81                four        85.0             27.0   7975.0
# 82                four        52.0             37.0   7995.0
# 86                four       100.0              0.0   9995.0
# 87                four       114.0             23.0  12940.0
# 88                four         0.0             23.0  13415.0
#
# [61 rows x 9 columns]

# %% [markdown]
# We can choose which column to be which value by dictionary: `{column_name : value}`

# %%
df.fillna({'wheel-base':90, 'horsepower':100})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       100.0             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five       100.0              NaN  17450.0
# ...                ...         ...              ...      ...
# 81                four        85.0             27.0   7975.0
# 82                four        52.0             37.0   7995.0
# 86                four       100.0              NaN   9995.0
# 87                four       114.0             23.0  12940.0
# 88                four       100.0             23.0  13415.0
#
# [61 rows x 9 columns]

# %% [markdown]
# #### `method = 'ffill'` / `'pad'` parameter
# `ffill` stands for *forward fill* - propagate last valid observation forward to next valid.

# %% [markdown]
# ---
# If we look at the data, we can see there're some values repeating. So it is logical that we get data about a vehicle from similar vehicle data.

# %%
df[df.company == 'audi']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4             NaN              NaN  17450.0
# 5           110.0             19.0  15250.0
# 6           110.0             19.0  18920.0

# %%
df[df.company == 'audi'].fillna(method='ffill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4           102.0             24.0  17450.0
# 5           110.0             19.0  15250.0
# 6           110.0             19.0  18920.0

# %% [markdown]
# #### `method='bfill'` / `'backfill'` parameter
# `bfill` stands for *back fill* - use next valid observation to fill gap.

# %%
df[df.company == 'toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df[df.company == 'toyota'].fillna(method='bfill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %% [markdown]
# The following method can be used to save changes to the original DF:

# %%
df[df.company=='toyota'] = df[df.company=='toyota'].fillna(method='bfill')

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %% [markdown]
# #### `limit` parameter
# `limit` parameter restricts the maximum number of consecutive `NaN` values to be filled by the method.

# %%
df.fillna(method='ffill', limit=2)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0             21.0  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five       102.0             24.0  17450.0
# ...                ...         ...              ...      ...
# 81                four        85.0             27.0   7975.0
# 82                four        52.0             37.0   7995.0
# 86                four       100.0             37.0   9995.0
# 87                four       114.0             23.0  12940.0
# 88                four       114.0             23.0  13415.0
#
# [61 rows x 9 columns]

# %% [markdown]
# #### fill `NaN` with `mean` values

# %%
# count models
for model in df['body-style'].unique():
    count = sum(df['body-style'] == model)
    print(f"{model}: {count}")
# Out:
# convertible: 3
# hatchback: 15
# sedan: 32
# wagon: 9
# hardtop: 2

# %%
dfs = df[df['body-style']=='sedan']
dfs.head()
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 9         bmw      sedan       101.2     NaN         ohc             four
# 10        bmw      sedan         NaN   176.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4             NaN              NaN  17450.0
# 5           110.0             19.0  15250.0
# 9             NaN             23.0  16430.0
# 10          101.0             23.0  16925.0

# %%
# mean column values
dfs.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# wheel-base           102.058333
# length               178.300000
# horsepower           113.166667
# average-mileage       23.727273
# price              17706.333333
# dtype: float64

# %%
# fill NaN values with mean of column
dfs.fillna(dfs.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#              company body-style  wheel-base  length engine-type  \
# index
# 3               audi      sedan   99.800000   176.6         ohc
# 4               audi      sedan   99.400000   176.6         ohc
# 5               audi      sedan   99.800000   177.3         ohc
# 9                bmw      sedan  101.200000   178.3         ohc
# 10               bmw      sedan  102.058333   176.8         ohc
# 11               bmw      sedan  101.200000   176.8         ohc
# 13               bmw      sedan  103.500000   189.0         ohc
# 14               bmw      sedan  103.500000   178.3         ohc
# 15               bmw      sedan  110.000000   197.0         ohc
# 18         chevrolet      sedan  102.058333   158.8         ohc
# 28             honda      sedan   96.500000   175.4         ohc
# 29             honda      sedan  102.058333   169.1         ohc
# 30             isuzu      sedan  102.058333   170.7         ohc
# 31             isuzu      sedan   94.500000   155.9         ohc
# 32             isuzu      sedan   94.500000   178.3         ohc
# 33            jaguar      sedan  113.000000   178.3        dohc
# 34            jaguar      sedan  113.000000   199.6        dohc
# 35            jaguar      sedan  102.058333   191.7        ohcv
# 43             mazda      sedan  104.900000   175.0         ohc
# 44     mercedes-benz      sedan  110.000000   190.9         NaN
# 46     mercedes-benz      sedan  120.900000   208.1         NaN
# 51        mitsubishi      sedan   96.300000   172.4         NaN
# 52        mitsubishi      sedan   96.300000   172.4         ohc
# 53            nissan      sedan  102.058333   178.3         ohc
# 54            nissan      sedan   94.500000   165.3         ohc
# 55            nissan      sedan  102.058333   165.3         ohc
# 57            nissan      sedan  100.400000   184.6        ohcv
# 80        volkswagen      sedan   97.300000   178.3         ohc
# 81        volkswagen      sedan   97.300000   171.7         ohc
# 82        volkswagen      sedan  102.058333   171.7         NaN
# 86        volkswagen      sedan   97.300000   178.3         ohc
# 87             volvo      sedan  104.300000   188.8         NaN
#
#       num-of-cylinders  horsepower  average-mileage         price
# index
# 3                 four  102.000000        24.000000  13950.000000
# 4                 five  113.166667        23.727273  17450.000000
# 5                 five  110.000000        19.000000  15250.000000
# 9                 four  113.166667        23.000000  16430.000000
# 10                four  101.000000        23.000000  16925.000000
# 11                 six  121.000000        23.727273  20970.000000
# 13                 six  113.166667        16.000000  30760.000000
# 14                 six  182.000000        16.000000  41315.000000
# 15                 six  182.000000        23.727273  36880.000000
# 18                four   70.000000        23.727273   6575.000000
# 28                four  101.000000        24.000000  12945.000000
# 29                four  113.166667        25.000000  10345.000000
# 30                four   78.000000        24.000000   6785.000000
# 31                four   70.000000        23.727273  17706.333333
# 32                four   70.000000        38.000000  17706.333333
# 33                 six  113.166667        15.000000  32250.000000
# 34                 six  176.000000        15.000000  35550.000000
# 35              twelve  262.000000        13.000000  36000.000000
# 43                four  113.166667        23.727273  18344.000000
# 44                five  123.000000        22.000000  25552.000000
# 46               eight  184.000000        14.000000  40960.000000
# 51                four   88.000000        23.727273   6989.000000
# 52                four  113.166667        25.000000   8189.000000
# 53                four   55.000000        23.727273   7099.000000
# 54                four   69.000000        31.000000   6649.000000
# 55                four   69.000000        31.000000   6849.000000
# 57                 six  152.000000        23.727273  13499.000000
# 80                four  113.166667        37.000000   7775.000000
# 81                four   85.000000        27.000000   7975.000000
# 82                four   52.000000        37.000000   7995.000000
# 86                four  100.000000        23.727273   9995.000000
# 87                four  114.000000        23.000000  12940.000000

# %%
# specifying by column names
df.fillna(
    {"horsepower" : np.mean(df["horsepower"]),
     "wheel-base" : np.mean(df["wheel-base"])}
)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000   168.8        dohc
# 1      alfa-romero  convertible   99.072917   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 4             audi        sedan   99.400000   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan   97.300000   171.7         ohc
# 82      volkswagen        sedan   99.072917   171.7         NaN
# 86      volkswagen        sedan   97.300000     NaN         ohc
# 87           volvo        sedan  104.300000   188.8         NaN
# 88           volvo        wagon  104.300000   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.297872             21.0  13495.0
# 1                 four  111.000000             21.0  16500.0
# 2                  six  154.000000              NaN  16500.0
# 3                 four  102.000000             24.0  13950.0
# 4                 five  108.297872              NaN  17450.0
# ...                ...         ...              ...      ...
# 81                four   85.000000             27.0   7975.0
# 82                four   52.000000             37.0   7995.0
# 86                four  100.000000              NaN   9995.0
# 87                four  114.000000             23.0  12940.0
# 88                four  108.297872             23.0  13415.0
#
# [61 rows x 9 columns]
