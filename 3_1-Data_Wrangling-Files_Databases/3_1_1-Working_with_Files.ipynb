# %% [markdown]
# ---
# # Data Science and Artificial Intelliegence Practicum
# ## 3.1-modul. Data Wrangling
# ---

# %% [markdown]
# ## 3.1.1 - Working with Files

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading files
#
# `read_pickle` - Load pickled pandas object (or any object) from file
#
# `read_table` - Read general delimited file into DataFrame
#
# `read_csv` - Read a comma-separated values (csv) file into DataFrame
#
# `read_clipboard` - Read text from clipboard and pass to read_csv
#
# `read_excel` - Read an Excel file into a pandas DataFrame
#
# `read_json` - Convert a JSON string to pandas object
#
# `read_html` - Read HTML tables into a list of DataFrame objects
#
# `read_hdf` - Read from the store, close it if we opened it
#
# `read_sql` - Read SQL query or database table into a DataFrame

# %% [markdown]
# #### `names` parameter
# List of column names to use. If the file contains a header row, then you should explicitly pass `header=0` to override the column names. Duplicates in this list are not allowed.

# %%
pd.read_csv("sample_data/california_housing_test.csv", 
            names=[1,2,3,4,6,7,8,9])
# Out:
#                      1                   2            3               4  \
# longitude     latitude  housing_median_age  total_rooms  total_bedrooms
# -122.050000  37.370000           27.000000  3885.000000      661.000000
# -118.300000  34.260000           43.000000  1510.000000      310.000000
# -117.810000  33.780000           27.000000  3589.000000      507.000000
# -118.360000  33.820000           28.000000    67.000000       15.000000
# ...                ...                 ...          ...             ...
# -119.860000  34.420000           23.000000  1450.000000      642.000000
# -118.140000  34.060000           27.000000  5257.000000     1082.000000
# -119.700000  36.300000           10.000000   956.000000      201.000000
# -117.120000  34.100000           40.000000    96.000000       14.000000
# -119.630000  34.420000           42.000000  1765.000000      263.000000
#
#                        6            7              8                   9
# longitude     population   households  median_income  median_house_value
# -122.050000  1537.000000   606.000000       6.608500       344700.000000
# -118.300000   809.000000   277.000000       3.599000       176500.000000
# -117.810000  1484.000000   495.000000       5.793400       270500.000000
# -118.360000    49.000000    11.000000       6.135900       330000.000000
# ...                  ...          ...            ...                 ...
# -119.860000  1258.000000   607.000000       1.179000       225000.000000
# -118.140000  3496.000000  1036.000000       3.390600       237200.000000
# -119.700000   693.000000   220.000000       2.289500        62000.000000
# -117.120000    46.000000    14.000000       3.270800       162500.000000
# -119.630000   753.000000   260.000000       8.560800       500001.000000
#
# [3001 rows x 8 columns]

# %% [markdown]
# #### `header` parameter
# Row number(s) to use as the column names, and the start of the data. If column names are passed explicitly then the behavior is identical to `header=None`. Explicitly pass `header=0` to be able to replace existing names.

# %%
pd.read_csv("sample_data/california_housing_test.csv", 
            names=[1,2,3,4,6,7,8,9], header=0)
# Out:
#              1     2       3       4       6       7       8         9
# -122.05  37.37  27.0  3885.0   661.0  1537.0   606.0  6.6085  344700.0
# -118.30  34.26  43.0  1510.0   310.0   809.0   277.0  3.5990  176500.0
# -117.81  33.78  27.0  3589.0   507.0  1484.0   495.0  5.7934  270500.0
# -118.36  33.82  28.0    67.0    15.0    49.0    11.0  6.1359  330000.0
# -119.67  36.33  19.0  1241.0   244.0   850.0   237.0  2.9375   81700.0
# ...        ...   ...     ...     ...     ...     ...     ...       ...
# -119.86  34.42  23.0  1450.0   642.0  1258.0   607.0  1.1790  225000.0
# -118.14  34.06  27.0  5257.0  1082.0  3496.0  1036.0  3.3906  237200.0
# -119.70  36.30  10.0   956.0   201.0   693.0   220.0  2.2895   62000.0
# -117.12  34.10  40.0    96.0    14.0    46.0    14.0  3.2708  162500.0
# -119.63  34.42  42.0  1765.0   263.0   753.0   260.0  8.5608  500001.0
#
# [3000 rows x 8 columns]

# %% [markdown]
# #### `index_col` parameter
# Column(s) to use as the row labels of the DataFrame, either given as string name or column index.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv",
            names=["hudud", "maydon", "aholi"], index_col=0)
df
# Out:
#                                         maydon       aholi
# hudud
# Boʻlinishi                     Maydoni (kv.km)     Aholisi
# Andijon viloyati                       4200.00  1899000.00
# Buxoro viloyati                       39400.00  1384700.00
# Fargʻona viloyati                      6800.00  2597000.00
# Jizzax viloyati                       20500.00   910500.00
# Xorazm viloyati                        6300.00  1200000.00
# Namangan viloyati                      7900.00  1862000.00
# Navoiy viloyati                      110800.00   767500.00
# Qashqadaryo viloyati                  28400.00  2029000.00
# Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# Samarqand viloyati                    16400.00  2322000.00
# Sirdaryo viloyati                      5100.00   648100.00
# Surxondaryo viloyati                  20800.00  1676000.00
# Toshkent viloyati                     15300.00  4450000.00

# %%
pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv",
            index_col="Aholisi")
# Out:
#                               Boʻlinishi  Maydoni (kv.km)
# Aholisi
# 1899000.0               Andijon viloyati           4200.0
# 1384700.0                Buxoro viloyati          39400.0
# 2597000.0              Fargʻona viloyati           6800.0
# 910500.0                 Jizzax viloyati          20500.0
# 1200000.0                Xorazm viloyati           6300.0
# 1862000.0              Namangan viloyati           7900.0
# 767500.0                 Navoiy viloyati         110800.0
# 2029000.0           Qashqadaryo viloyati          28400.0
# 1200000.0  Qoraqalpogʻiston Respublikasi         160000.0
# 2322000.0             Samarqand viloyati          16400.0
# 648100.0               Sirdaryo viloyati           5100.0
# 1676000.0           Surxondaryo viloyati          20800.0
# 4450000.0              Toshkent viloyati          15300.0

# %% [markdown]
# #### `sep` parameter
# Delimiter to use. Default ","

# %%
pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv',
            sep=",").head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %% [markdown]
# #### `nrows` parameter
# Number of rows of file to read. Useful for reading pieces of large files.

# %%
pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/global_earthquake.csv',
            index_col=0, nrows=15)
# Out:
#                 Time  Latitude  Longitude        Type  Depth  Depth Error  \
# Date
# 01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
# 01/10/1965  13:36:32   -13.405    166.629  Earthquake   35.0          NaN
# 01/12/1965  13:32:25    27.357     87.867  Earthquake   20.0          NaN
# 01/15/1965  23:17:42   -13.309    166.212  Earthquake   35.0          NaN
# 01/16/1965  11:32:37   -56.452    -27.043  Earthquake   95.0          NaN
# 01/17/1965  10:43:17   -24.563    178.487  Earthquake  565.0          NaN
# 01/17/1965  20:57:41    -6.807    108.988  Earthquake  227.9          NaN
# 01/24/1965  00:11:17    -2.608    125.952  Earthquake   20.0          NaN
# 01/29/1965  09:35:30    54.636    161.703  Earthquake   55.0          NaN
# 02/01/1965  05:27:06   -18.697   -177.864  Earthquake  482.9          NaN
# 02/02/1965  15:56:51    37.523     73.251  Earthquake   15.0          NaN
#
#             Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# Date
# 01/02/1965                     NaN        6.0             MW              NaN
# 01/04/1965                     NaN        5.8             MW              NaN
# 01/05/1965                     NaN        6.2             MW              NaN
# 01/08/1965                     NaN        5.8             MW              NaN
# 01/09/1965                     NaN        5.8             MW              NaN
# 01/10/1965                     NaN        6.7             MW              NaN
# 01/12/1965                     NaN        5.9             MW              NaN
# 01/15/1965                     NaN        6.0             MW              NaN
# 01/16/1965                     NaN        6.0             MW              NaN
# 01/17/1965                     NaN        5.8             MW              NaN
# 01/17/1965                     NaN        5.9             MW              NaN
# 01/24/1965                     NaN        8.2             MW              NaN
# 01/29/1965                     NaN        5.5             MW              NaN
# 02/01/1965                     NaN        5.6             MW              NaN
# 02/02/1965                     NaN        6.0             MW              NaN
#
#             Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# Date
# 01/02/1965                         NaN            NaN                  NaN
# 01/04/1965                         NaN            NaN                  NaN
# 01/05/1965                         NaN            NaN                  NaN
# 01/08/1965                         NaN            NaN                  NaN
# 01/09/1965                         NaN            NaN                  NaN
# 01/10/1965                         NaN            NaN                  NaN
# 01/12/1965                         NaN            NaN                  NaN
# 01/15/1965                         NaN            NaN                  NaN
# 01/16/1965                         NaN            NaN                  NaN
# 01/17/1965                         NaN            NaN                  NaN
# 01/17/1965                         NaN            NaN                  NaN
# 01/24/1965                         NaN            NaN                  NaN
# 01/29/1965                         NaN            NaN                  NaN
# 02/01/1965                         NaN            NaN                  NaN
# 02/02/1965                         NaN            NaN                  NaN
#
#             Horizontal Error  Root Mean Square               ID     Source  \
# Date
# 01/02/1965               NaN               NaN     ISCGEM860706     ISCGEM
# 01/04/1965               NaN               NaN     ISCGEM860737     ISCGEM
# 01/05/1965               NaN               NaN     ISCGEM860762     ISCGEM
# 01/08/1965               NaN               NaN     ISCGEM860856     ISCGEM
# 01/09/1965               NaN               NaN     ISCGEM860890     ISCGEM
# 01/10/1965               NaN               NaN     ISCGEM860922     ISCGEM
# 01/12/1965               NaN               NaN     ISCGEM861007     ISCGEM
# 01/15/1965               NaN               NaN     ISCGEM861111     ISCGEM
# 01/16/1965               NaN               NaN  ISCGEMSUP861125  ISCGEMSUP
# 01/17/1965               NaN               NaN     ISCGEM861148     ISCGEM
# 01/17/1965               NaN               NaN     ISCGEM861155     ISCGEM
# 01/24/1965               NaN               NaN     ISCGEM861299     ISCGEM
# 01/29/1965               NaN               NaN     ISCGEM861461     ISCGEM
# 02/01/1965               NaN               NaN     ISCGEM859136     ISCGEM
# 02/02/1965               NaN               NaN     ISCGEM859164     ISCGEM
#
#            Location Source Magnitude Source     Status
# Date
# 01/02/1965          ISCGEM           ISCGEM  Automatic
# 01/04/1965          ISCGEM           ISCGEM  Automatic
# 01/05/1965          ISCGEM           ISCGEM  Automatic
# 01/08/1965          ISCGEM           ISCGEM  Automatic
# 01/09/1965          ISCGEM           ISCGEM  Automatic
# 01/10/1965          ISCGEM           ISCGEM  Automatic
# 01/12/1965          ISCGEM           ISCGEM  Automatic
# 01/15/1965          ISCGEM           ISCGEM  Automatic
# 01/16/1965          ISCGEM           ISCGEM  Automatic
# 01/17/1965          ISCGEM           ISCGEM  Automatic
# 01/17/1965          ISCGEM           ISCGEM  Automatic
# 01/24/1965          ISCGEM           ISCGEM  Automatic
# 01/29/1965          ISCGEM           ISCGEM  Automatic
# 02/01/1965          ISCGEM           ISCGEM  Automatic
# 02/02/1965          ISCGEM           ISCGEM  Automatic

# %% [markdown]
# ### Writing files

# %%
df
# Out:
#                                         maydon       aholi
# hudud
# Boʻlinishi                     Maydoni (kv.km)     Aholisi
# Andijon viloyati                       4200.00  1899000.00
# Buxoro viloyati                       39400.00  1384700.00
# Fargʻona viloyati                      6800.00  2597000.00
# Jizzax viloyati                       20500.00   910500.00
# Xorazm viloyati                        6300.00  1200000.00
# Namangan viloyati                      7900.00  1862000.00
# Navoiy viloyati                      110800.00   767500.00
# Qashqadaryo viloyati                  28400.00  2029000.00
# Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# Samarqand viloyati                    16400.00  2322000.00
# Sirdaryo viloyati                      5100.00   648100.00
# Surxondaryo viloyati                  20800.00  1676000.00
# Toshkent viloyati                     15300.00  4450000.00

# %%
# write object to a comma-separated values (csv) file
df.to_csv("uzb_data.csv")

# %%
ser_obj = df.maydon
ser_obj
# Out:
# hudud
# Boʻlinishi                       Maydoni (kv.km)
# Andijon viloyati                         4200.00
# Buxoro viloyati                         39400.00
# Fargʻona viloyati                        6800.00
# Jizzax viloyati                         20500.00
# Xorazm viloyati                          6300.00
# Namangan viloyati                        7900.00
# Navoiy viloyati                        110800.00
# Qashqadaryo viloyati                    28400.00
# Qoraqalpogʻiston Respublikasi          160000.00
# Samarqand viloyati                      16400.00
# Sirdaryo viloyati                        5100.00
# Surxondaryo viloyati                    20800.00
# Toshkent viloyati                       15300.00
# Name: maydon, dtype: object

# %%
ser_obj.to_csv("uzb_maydon.csv")

# %% [markdown]
# #### `squeeze`
# If the parsed data only contains one column then return a Series

# %%
pd.read_csv("uzb_maydon.csv", squeeze=True, index_col=0)
# Out:
# hudud
# Boʻlinishi                       Maydoni (kv.km)
# Andijon viloyati                         4200.00
# Buxoro viloyati                         39400.00
# Fargʻona viloyati                        6800.00
# Jizzax viloyati                         20500.00
# Xorazm viloyati                          6300.00
# Namangan viloyati                        7900.00
# Navoiy viloyati                        110800.00
# Qashqadaryo viloyati                    28400.00
# Qoraqalpogʻiston Respublikasi          160000.00
# Samarqand viloyati                      16400.00
# Sirdaryo viloyati                        5100.00
# Surxondaryo viloyati                    20800.00
# Toshkent viloyati                       15300.00
# Name: maydon, dtype: object

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv',
                  index_col=0)
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0
# ...                ...         ...              ...      ...
# 81                four          85               27   7975.0
# 82                four          52               37   7995.0
# 86                four         100               26   9995.0
# 87                four         114               23  12940.0
# 88                four         114               23  13415.0
#
# [61 rows x 9 columns]

# %% [markdown]
# #### drop index

# %%
df2.to_excel("auto_data.xlsx", index=False)

# %%
pd.read_excel("auto_data.xlsx")
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 0          111               21  13495.0
# 1          111               21  16500.0
# 2          154               19  16500.0
# 3          102               24  13950.0
# 4          115               18  17450.0
# ..         ...              ...      ...
# 56          85               27   7975.0
# 57          52               37   7995.0
# 58         100               26   9995.0
# 59         114               23  12940.0
# 60         114               23  13415.0
#
# [61 rows x 9 columns]

# %% [markdown]
# #### write only certain columns

# %%
df2.to_excel("auto_data.xlsx",
             index=False,
             columns=['company','body-style','engine-type','horsepower','price']
             )

# %%
pd.read_excel("auto_data.xlsx")
# Out:
#         company   body-style engine-type  horsepower    price
# 0   alfa-romero  convertible        dohc         111  13495.0
# 1   alfa-romero  convertible        dohc         111  16500.0
# 2   alfa-romero    hatchback        ohcv         154  16500.0
# 3          audi        sedan         ohc         102  13950.0
# 4          audi        sedan         ohc         115  17450.0
# ..          ...          ...         ...         ...      ...
# 56   volkswagen        sedan         ohc          85   7975.0
# 57   volkswagen        sedan         ohc          52   7995.0
# 58   volkswagen        sedan         ohc         100   9995.0
# 59        volvo        sedan         ohc         114  12940.0
# 60        volvo        wagon         ohc         114  13415.0
#
# [61 rows x 5 columns]

# %% [markdown]
# ### HDF5 format
# Hierarchical Data Format (HDF)

# %% [markdown]
# #### `pandas.HDFStore`

# %%
hdfobj = pd.HDFStore("data.h5")

# %% [markdown]
# add data to hdf object

# %%
hdfobj['uzdata'] = df

# %%
hdfobj['cardata'] = df2

# %% [markdown]
# We can call elements like dictionary in hdf object

# %%
hdfobj['uzdata']
# Out:
#                                         maydon       aholi
# hudud
# Boʻlinishi                     Maydoni (kv.km)     Aholisi
# Andijon viloyati                       4200.00  1899000.00
# Buxoro viloyati                       39400.00  1384700.00
# Fargʻona viloyati                      6800.00  2597000.00
# Jizzax viloyati                       20500.00   910500.00
# Xorazm viloyati                        6300.00  1200000.00
# Namangan viloyati                      7900.00  1862000.00
# Navoiy viloyati                      110800.00   767500.00
# Qashqadaryo viloyati                  28400.00  2029000.00
# Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# Samarqand viloyati                    16400.00  2322000.00
# Sirdaryo viloyati                      5100.00   648100.00
# Surxondaryo viloyati                  20800.00  1676000.00
# Toshkent viloyati                     15300.00  4450000.00

# %% [markdown]
# After saving data, we should `close()` hdf object

# %%
hdfobj.close()

# %% [markdown]
# #### `pandas.to_hdf` method
# Write the contained data to an HDF5 file using HDFStore

# %%
df.to_hdf("uzdata.h5", key='uzdata')

# %% [markdown]
# For reading HDF5 files we can use either `HDFStore` or `read_hdf` method

# %%
data = pd.HDFStore("data.h5", mode='r')

# %%
# return a list of keys corresponding to objects stored in HDFStore
data.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
data['uzdata'].head()
# Out:
#                             maydon       aholi
# hudud
# Boʻlinishi         Maydoni (kv.km)     Aholisi
# Andijon viloyati           4200.00  1899000.00
# Buxoro viloyati           39400.00  1384700.00
# Fargʻona viloyati          6800.00  2597000.00
# Jizzax viloyati           20500.00   910500.00

# %%
data.close()

# %%
pd.read_hdf('uzdata.h5', key='uzdata')
# Out:
#                                         maydon       aholi
# hudud
# Boʻlinishi                     Maydoni (kv.km)     Aholisi
# Andijon viloyati                       4200.00  1899000.00
# Buxoro viloyati                       39400.00  1384700.00
# Fargʻona viloyati                      6800.00  2597000.00
# Jizzax viloyati                       20500.00   910500.00
# Xorazm viloyati                        6300.00  1200000.00
# Namangan viloyati                      7900.00  1862000.00
# Navoiy viloyati                      110800.00   767500.00
# Qashqadaryo viloyati                  28400.00  2029000.00
# Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# Samarqand viloyati                    16400.00  2322000.00
# Sirdaryo viloyati                      5100.00   648100.00
# Surxondaryo viloyati                  20800.00  1676000.00
# Toshkent viloyati                     15300.00  4450000.00
